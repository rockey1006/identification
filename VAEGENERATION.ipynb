# %% [markdown]
# <a href="https://colab.research.google.com/github/rockey1006/identification/blob/main/VAEGENERATION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from zipfile import ZipFile
with ZipFile('/content/drive/MyDrive/batchwrong.zip', 'r') as zipObj:
   # Extract all the contents of zip file in different directory
   zipObj.extractall('wrong')

# %%
import os


path = '/content/wrong/content/batchwrong/batch006/'
count = 1
for file in os.listdir(path):
    if os.path.isfile(os.path.join(path,file))==True:
        newname = '%06d'%(count)+'.png'
        os.rename(os.path.join(path, file), os.path.join(path, newname))
        count+=1

# %%
# !git clone https://github.com/rockey1006/facenet.git
# !pip uninstall tensorflow
# !pip install tensorflow==1.13.2
# !pip install scipy==1.2.1
# !pip install facenet

# %%
from zipfile import ZipFile
with ZipFile('/content/drive/My Drive/20170708-150701.zip', 'r') as zipObj:
   # Extract all the contents of zip file in different directory
   zipObj.extractall('/content/facenet/cnn')

# %%
# !python facenet/src/generative/calculate_attribute_vectors.py \
facenet.src.generative.models.dfc_vae \
/content/facenet/cnn/20170708-150701/model.ckpt-50000 \
/content/wrong/content/batchwrong/batch006 \
--annotations_filename /list.txt \
--output_filename attribute.h5 \
--batch_size 128 \
--image_size 160 \
--latent_var_size 100
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING:tensorflow:From facenet/src/generative/calculate_attribute_vectors.py:72: slice_input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(tuple(tensor_list)).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/input.py:374: range_input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.range(limit).shuffle(limit).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/input.py:320: input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(input_tensor).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/input.py:190: limit_epochs (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensors(tensor).repeat(num_epochs)`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/input.py:113: RefVariable.count_up_to (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Prefer Dataset.range instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/variables.py:2132: count_up_to (from tensorflow.python.ops.state_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Prefer Dataset.range instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/input.py:199: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/input.py:199: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/input.py:202: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From facenet/src/generative/calculate_attribute_vectors.py:92: batch_join (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.interleave(...).batch(batch_size)` (or `padded_batch(...)` if `dynamic_pad=True`).
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/layers/python/layers/layers.py:1624: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# 2021-01-18 08:00:06.995457: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2021-01-18 08:00:06.998689: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2000170000 Hz
# 2021-01-18 08:00:06.998977: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x3092260 executing computations on platform Host. Devices:
# 2021-01-18 08:00:06.999013: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# WARNING:tensorflow:From facenet/src/generative/calculate_attribute_vectors.py:117: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# Restoring VAE checkpoint: /content/facenet/cnn/20170708-150701/model.ckpt-50000
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# Batch 1/1: 0.133 seconds
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# Writing attribute vectors, latent variables and attributes to attribute.h5

# %%
from zipfile import ZipFile
with ZipFile('/content/drive/My Drive/20170708-150701.zip', 'r') as zipObj:
   # Extract all the contents of zip file in different directory
   zipObj.extractall('/content/facenet/cnn')

# %%
import os
 
 
def mkd():
    path = "/content/batch006/batch" #创建的文件的位置
    for i in range(1, 35):#创建名为01-64的文件夹
        k = "%02d" % i
        file_name = path + str(k) 
        os.makedirs(file_name)
        i = i+1
        
        
mkd()

# %%
# !python facenet/src/generative/modify_attribute.py \
facenet.src.generative.models.dfc_vae \
/content/facenet/cnn/20170708-150701/model.ckpt-50000 \
/content/facenet/cnn/20170708-150701/attribute_vectors.h5 \
/content/attribute.h5  \
/content/batch006/batch29/a.png  \
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/layers/python/layers/layers.py:1624: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# 2021-01-18 08:13:03.035620: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2021-01-18 08:13:03.040005: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2000170000 Hz
# 2021-01-18 08:13:03.040335: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x19d3e40 executing computations on platform Host. Devices:
# 2021-01-18 08:13:03.040369: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# WARNING:tensorflow:From facenet/src/generative/modify_attribute.py:87: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:`tf.train.start_queue_runners()` was called when no queue runners were defined. You can safely remove the call to this deprecated function.
# Restoring VAE checkpoint: /content/facenet/cnn/20170708-150701/model.ckpt-50000
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# Writing generated image to /content/batch006/batch29/a.png
# WARNING:root:Lossy conversion from float32 to uint8. Range [46.85348129272461, 253.55023193359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.5988655090332, 250.6508026123047]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.252742767333984, 246.98934936523438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.51967239379883, 247.49349975585938]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.73385238647461, 248.21804809570312]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.07733917236328, 249.22877502441406]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [42.411888122558594, 250.50811767578125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [40.341461181640625, 253.13662719726562]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [38.100250244140625, 262.5857849121094]. Convert image to uint8 prior to saving to suppress this warning.
# Writing generated image to /content/batch006/batch29/a.png
# WARNING:root:Lossy conversion from float32 to uint8. Range [46.85348129272461, 253.55023193359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.5988655090332, 250.6508026123047]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.252742767333984, 246.98934936523438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.51967239379883, 247.49349975585938]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.73385238647461, 248.21804809570312]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.07733917236328, 249.22877502441406]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [42.411888122558594, 250.50811767578125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [40.341461181640625, 253.13662719726562]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [38.100250244140625, 262.5857849121094]. Convert image to uint8 prior to saving to suppress this warning.
# Writing generated image to /content/batch006/batch29/a.png
# WARNING:root:Lossy conversion from float32 to uint8. Range [46.85348129272461, 253.55023193359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.5988655090332, 250.6508026123047]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.252742767333984, 246.98934936523438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.51967239379883, 247.49349975585938]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.73385238647461, 248.21804809570312]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.07733917236328, 249.22877502441406]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [42.411888122558594, 250.50811767578125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [40.341461181640625, 253.13662719726562]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [38.100250244140625, 262.5857849121094]. Convert image to uint8 prior to saving to suppress this warning.
# Writing generated image to /content/batch006/batch29/a.png
# WARNING:root:Lossy conversion from float32 to uint8. Range [46.85348129272461, 253.55023193359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.5988655090332, 250.6508026123047]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.252742767333984, 246.98934936523438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.51967239379883, 247.49349975585938]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.73385238647461, 248.21804809570312]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.07733917236328, 249.22877502441406]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [42.411888122558594, 250.50811767578125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [40.341461181640625, 253.13662719726562]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [38.100250244140625, 262.5857849121094]. Convert image to uint8 prior to saving to suppress this warning.
# Writing generated image to /content/batch006/batch29/a.png
# WARNING:root:Lossy conversion from float32 to uint8. Range [46.85348129272461, 253.55023193359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.5988655090332, 250.6508026123047]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.252742767333984, 246.98934936523438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.51967239379883, 247.49349975585938]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.73385238647461, 248.21804809570312]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.07733917236328, 249.22877502441406]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [42.411888122558594, 250.50811767578125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [40.341461181640625, 253.13662719726562]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [38.100250244140625, 262.5857849121094]. Convert image to uint8 prior to saving to suppress this warning.
# Writing generated image to /content/batch006/batch29/a.png
# WARNING:root:Lossy conversion from float32 to uint8. Range [46.85348129272461, 253.55023193359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.5988655090332, 250.6508026123047]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.252742767333984, 246.98934936523438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.51967239379883, 247.49349975585938]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.73385238647461, 248.21804809570312]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.07733917236328, 249.22877502441406]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [42.411888122558594, 250.50811767578125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [40.341461181640625, 253.13662719726562]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [38.100250244140625, 262.5857849121094]. Convert image to uint8 prior to saving to suppress this warning.
# Writing generated image to /content/batch006/batch29/a.png
# WARNING:root:Lossy conversion from float32 to uint8. Range [46.85348129272461, 253.55023193359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.5988655090332, 250.6508026123047]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.252742767333984, 246.98934936523438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.51967239379883, 247.49349975585938]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.73385238647461, 248.21804809570312]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.07733917236328, 249.22877502441406]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [42.411888122558594, 250.50811767578125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [40.341461181640625, 253.13662719726562]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [38.100250244140625, 262.5857849121094]. Convert image to uint8 prior to saving to suppress this warning.
# Writing generated image to /content/batch006/batch29/a.png
# WARNING:root:Lossy conversion from float32 to uint8. Range [46.85348129272461, 253.55023193359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.5988655090332, 250.6508026123047]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.252742767333984, 246.98934936523438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.51967239379883, 247.49349975585938]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.73385238647461, 248.21804809570312]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.07733917236328, 249.22877502441406]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [42.411888122558594, 250.50811767578125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [40.341461181640625, 253.13662719726562]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [38.100250244140625, 262.5857849121094]. Convert image to uint8 prior to saving to suppress this warning.
# Writing generated image to /content/batch006/batch29/a.png
# WARNING:root:Lossy conversion from float32 to uint8. Range [46.85348129272461, 253.55023193359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.5988655090332, 250.6508026123047]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.252742767333984, 246.98934936523438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.51967239379883, 247.49349975585938]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.73385238647461, 248.21804809570312]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.07733917236328, 249.22877502441406]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [42.411888122558594, 250.50811767578125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [40.341461181640625, 253.13662719726562]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [38.100250244140625, 262.5857849121094]. Convert image to uint8 prior to saving to suppress this warning.
# Writing generated image to /content/batch006/batch29/a.png
# WARNING:root:Lossy conversion from float32 to uint8. Range [46.85348129272461, 253.55023193359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.5988655090332, 250.6508026123047]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.252742767333984, 246.98934936523438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.51967239379883, 247.49349975585938]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.73385238647461, 248.21804809570312]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.07733917236328, 249.22877502441406]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [42.411888122558594, 250.50811767578125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [40.341461181640625, 253.13662719726562]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [38.100250244140625, 262.5857849121094]. Convert image to uint8 prior to saving to suppress this warning.
# Writing generated image to /content/batch006/batch29/a.png
# WARNING:root:Lossy conversion from float32 to uint8. Range [46.85348129272461, 253.55023193359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.5988655090332, 250.6508026123047]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.252742767333984, 246.98934936523438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.51967239379883, 247.49349975585938]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.73385238647461, 248.21804809570312]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.07733917236328, 249.22877502441406]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [42.411888122558594, 250.50811767578125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [40.341461181640625, 253.13662719726562]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [38.100250244140625, 262.5857849121094]. Convert image to uint8 prior to saving to suppress this warning.
# Writing generated image to /content/batch006/batch29/a.png
# WARNING:root:Lossy conversion from float32 to uint8. Range [46.85348129272461, 253.55023193359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.5988655090332, 250.6508026123047]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.252742767333984, 246.98934936523438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.51967239379883, 247.49349975585938]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.73385238647461, 248.21804809570312]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.07733917236328, 249.22877502441406]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [42.411888122558594, 250.50811767578125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [40.341461181640625, 253.13662719726562]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [38.100250244140625, 262.5857849121094]. Convert image to uint8 prior to saving to suppress this warning.
# Writing generated image to /content/batch006/batch29/a.png
# WARNING:root:Lossy conversion from float32 to uint8. Range [46.85348129272461, 253.55023193359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.5988655090332, 250.6508026123047]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.252742767333984, 246.98934936523438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.51967239379883, 247.49349975585938]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.73385238647461, 248.21804809570312]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.07733917236328, 249.22877502441406]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [42.411888122558594, 250.50811767578125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [40.341461181640625, 253.13662719726562]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [38.100250244140625, 262.5857849121094]. Convert image to uint8 prior to saving to suppress this warning.
# Writing generated image to /content/batch006/batch29/a.png
# WARNING:root:Lossy conversion from float32 to uint8. Range [46.85348129272461, 253.55023193359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.5988655090332, 250.6508026123047]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.252742767333984, 246.98934936523438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.51967239379883, 247.49349975585938]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.73385238647461, 248.21804809570312]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.07733917236328, 249.22877502441406]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [42.411888122558594, 250.50811767578125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [40.341461181640625, 253.13662719726562]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [38.100250244140625, 262.5857849121094]. Convert image to uint8 prior to saving to suppress this warning.
# Writing generated image to /content/batch006/batch29/a.png
# WARNING:root:Lossy conversion from float32 to uint8. Range [46.85348129272461, 253.55023193359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.5988655090332, 250.6508026123047]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.252742767333984, 246.98934936523438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.51967239379883, 247.49349975585938]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.73385238647461, 248.21804809570312]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.07733917236328, 249.22877502441406]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [42.411888122558594, 250.50811767578125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [40.341461181640625, 253.13662719726562]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [38.100250244140625, 262.5857849121094]. Convert image to uint8 prior to saving to suppress this warning.
# Writing generated image to /content/batch006/batch29/a.png
# WARNING:root:Lossy conversion from float32 to uint8. Range [46.85348129272461, 253.55023193359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.5988655090332, 250.6508026123047]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.252742767333984, 246.98934936523438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.51967239379883, 247.49349975585938]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.73385238647461, 248.21804809570312]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.07733917236328, 249.22877502441406]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [42.411888122558594, 250.50811767578125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [40.341461181640625, 253.13662719726562]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [38.100250244140625, 262.5857849121094]. Convert image to uint8 prior to saving to suppress this warning.
# Writing generated image to /content/batch006/batch29/a.png
# WARNING:root:Lossy conversion from float32 to uint8. Range [46.85348129272461, 253.55023193359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.5988655090332, 250.6508026123047]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.252742767333984, 246.98934936523438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.51967239379883, 247.49349975585938]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.73385238647461, 248.21804809570312]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.07733917236328, 249.22877502441406]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [42.411888122558594, 250.50811767578125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [40.341461181640625, 253.13662719726562]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [38.100250244140625, 262.5857849121094]. Convert image to uint8 prior to saving to suppress this warning.
# Writing generated image to /content/batch006/batch29/a.png
# WARNING:root:Lossy conversion from float32 to uint8. Range [46.85348129272461, 253.55023193359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.5988655090332, 250.6508026123047]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.252742767333984, 246.98934936523438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.51967239379883, 247.49349975585938]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.73385238647461, 248.21804809570312]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.07733917236328, 249.22877502441406]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [42.411888122558594, 250.50811767578125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [40.341461181640625, 253.13662719726562]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [38.100250244140625, 262.5857849121094]. Convert image to uint8 prior to saving to suppress this warning.
# Writing generated image to /content/batch006/batch29/a.png
# WARNING:root:Lossy conversion from float32 to uint8. Range [46.85348129272461, 253.55023193359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.5988655090332, 250.6508026123047]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.252742767333984, 246.98934936523438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.51967239379883, 247.49349975585938]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.73385238647461, 248.21804809570312]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.07733917236328, 249.22877502441406]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [42.411888122558594, 250.50811767578125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [40.341461181640625, 253.13662719726562]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [38.100250244140625, 262.5857849121094]. Convert image to uint8 prior to saving to suppress this warning.
# Writing generated image to /content/batch006/batch29/a.png
# WARNING:root:Lossy conversion from float32 to uint8. Range [46.85348129272461, 253.55023193359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.5988655090332, 250.6508026123047]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.252742767333984, 246.98934936523438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.51967239379883, 247.49349975585938]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.73385238647461, 248.21804809570312]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.07733917236328, 249.22877502441406]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [42.411888122558594, 250.50811767578125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [40.341461181640625, 253.13662719726562]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [38.100250244140625, 262.5857849121094]. Convert image to uint8 prior to saving to suppress this warning.
# Writing generated image to /content/batch006/batch29/a.png
# WARNING:root:Lossy conversion from float32 to uint8. Range [46.85348129272461, 253.55023193359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.5988655090332, 250.6508026123047]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.252742767333984, 246.98934936523438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.51967239379883, 247.49349975585938]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.73385238647461, 248.21804809570312]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.07733917236328, 249.22877502441406]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [42.411888122558594, 250.50811767578125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [40.341461181640625, 253.13662719726562]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [38.100250244140625, 262.5857849121094]. Convert image to uint8 prior to saving to suppress this warning.
# Writing generated image to /content/batch006/batch29/a.png
# WARNING:root:Lossy conversion from float32 to uint8. Range [46.85348129272461, 253.55023193359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.5988655090332, 250.6508026123047]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.252742767333984, 246.98934936523438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.51967239379883, 247.49349975585938]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.73385238647461, 248.21804809570312]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.07733917236328, 249.22877502441406]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [42.411888122558594, 250.50811767578125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [40.341461181640625, 253.13662719726562]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [38.100250244140625, 262.5857849121094]. Convert image to uint8 prior to saving to suppress this warning.
# Writing generated image to /content/batch006/batch29/a.png
# WARNING:root:Lossy conversion from float32 to uint8. Range [46.85348129272461, 253.55023193359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.5988655090332, 250.6508026123047]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.252742767333984, 246.98934936523438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.51967239379883, 247.49349975585938]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.73385238647461, 248.21804809570312]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.07733917236328, 249.22877502441406]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [42.411888122558594, 250.50811767578125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [40.341461181640625, 253.13662719726562]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [38.100250244140625, 262.5857849121094]. Convert image to uint8 prior to saving to suppress this warning.
# Writing generated image to /content/batch006/batch29/a.png
# WARNING:root:Lossy conversion from float32 to uint8. Range [46.85348129272461, 253.55023193359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.5988655090332, 250.6508026123047]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.252742767333984, 246.98934936523438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.51967239379883, 247.49349975585938]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.73385238647461, 248.21804809570312]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.07733917236328, 249.22877502441406]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [42.411888122558594, 250.50811767578125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [40.341461181640625, 253.13662719726562]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [38.100250244140625, 262.5857849121094]. Convert image to uint8 prior to saving to suppress this warning.
# Writing generated image to /content/batch006/batch29/a.png
# WARNING:root:Lossy conversion from float32 to uint8. Range [46.85348129272461, 253.55023193359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.5988655090332, 250.6508026123047]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.252742767333984, 246.98934936523438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.51967239379883, 247.49349975585938]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.73385238647461, 248.21804809570312]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.07733917236328, 249.22877502441406]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [42.411888122558594, 250.50811767578125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [40.341461181640625, 253.13662719726562]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [38.100250244140625, 262.5857849121094]. Convert image to uint8 prior to saving to suppress this warning.
# Writing generated image to /content/batch006/batch29/a.png
# WARNING:root:Lossy conversion from float32 to uint8. Range [46.85348129272461, 253.55023193359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.5988655090332, 250.6508026123047]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.252742767333984, 246.98934936523438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.51967239379883, 247.49349975585938]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.73385238647461, 248.21804809570312]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.07733917236328, 249.22877502441406]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [42.411888122558594, 250.50811767578125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [40.341461181640625, 253.13662719726562]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [38.100250244140625, 262.5857849121094]. Convert image to uint8 prior to saving to suppress this warning.
# Writing generated image to /content/batch006/batch29/a.png
# WARNING:root:Lossy conversion from float32 to uint8. Range [46.85348129272461, 253.55023193359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.5988655090332, 250.6508026123047]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.252742767333984, 246.98934936523438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.51967239379883, 247.49349975585938]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.73385238647461, 248.21804809570312]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.07733917236328, 249.22877502441406]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [42.411888122558594, 250.50811767578125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [40.341461181640625, 253.13662719726562]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [38.100250244140625, 262.5857849121094]. Convert image to uint8 prior to saving to suppress this warning.
# Writing generated image to /content/batch006/batch29/a.png
# WARNING:root:Lossy conversion from float32 to uint8. Range [46.85348129272461, 253.55023193359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.5988655090332, 250.6508026123047]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.252742767333984, 246.98934936523438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.51967239379883, 247.49349975585938]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.73385238647461, 248.21804809570312]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.07733917236328, 249.22877502441406]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [42.411888122558594, 250.50811767578125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [40.341461181640625, 253.13662719726562]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [38.100250244140625, 262.5857849121094]. Convert image to uint8 prior to saving to suppress this warning.
# Writing generated image to /content/batch006/batch29/a.png
# WARNING:root:Lossy conversion from float32 to uint8. Range [46.85348129272461, 253.55023193359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.5988655090332, 250.6508026123047]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.252742767333984, 246.98934936523438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.51967239379883, 247.49349975585938]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.73385238647461, 248.21804809570312]. Convert image to uint8 prior to saving to suppress this warning.
# ...
# WARNING:root:Lossy conversion from float32 to uint8. Range [42.411888122558594, 250.50811767578125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [40.341461181640625, 253.13662719726562]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [38.100250244140625, 262.5857849121094]. Convert image to uint8 prior to saving to suppress this warning.
# Writing generated image to /content/batch006/batch29/a.png
# WARNING:root:Lossy conversion from float32 to uint8. Range [46.85348129272461, 253.55023193359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.5988655090332, 250.6508026123047]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.252742767333984, 246.98934936523438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.51967239379883, 247.49349975585938]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.73385238647461, 248.21804809570312]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.07733917236328, 249.22877502441406]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [42.411888122558594, 250.50811767578125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [40.341461181640625, 253.13662719726562]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [38.100250244140625, 262.5857849121094]. Convert image to uint8 prior to saving to suppress this warning.
# Writing generated image to /content/batch006/batch29/a.png
# WARNING:root:Lossy conversion from float32 to uint8. Range [46.85348129272461, 253.55023193359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.5988655090332, 250.6508026123047]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.252742767333984, 246.98934936523438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.51967239379883, 247.49349975585938]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.73385238647461, 248.21804809570312]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.07733917236328, 249.22877502441406]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [42.411888122558594, 250.50811767578125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [40.341461181640625, 253.13662719726562]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [38.100250244140625, 262.5857849121094]. Convert image to uint8 prior to saving to suppress this warning.
# Writing generated image to /content/batch006/batch29/a.png
# WARNING:root:Lossy conversion from float32 to uint8. Range [46.85348129272461, 253.55023193359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.5988655090332, 250.6508026123047]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.252742767333984, 246.98934936523438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.51967239379883, 247.49349975585938]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.73385238647461, 248.21804809570312]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.07733917236328, 249.22877502441406]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [42.411888122558594, 250.50811767578125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [40.341461181640625, 253.13662719726562]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [38.100250244140625, 262.5857849121094]. Convert image to uint8 prior to saving to suppress this warning.
# Writing generated image to /content/batch006/batch29/a.png
# WARNING:root:Lossy conversion from float32 to uint8. Range [46.85348129272461, 253.55023193359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.5988655090332, 250.6508026123047]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.252742767333984, 246.98934936523438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.51967239379883, 247.49349975585938]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.73385238647461, 248.21804809570312]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.07733917236328, 249.22877502441406]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [42.411888122558594, 250.50811767578125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [40.341461181640625, 253.13662719726562]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [38.100250244140625, 262.5857849121094]. Convert image to uint8 prior to saving to suppress this warning.
# Writing generated image to /content/batch006/batch29/a.png
# WARNING:root:Lossy conversion from float32 to uint8. Range [46.85348129272461, 253.55023193359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.5988655090332, 250.6508026123047]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.252742767333984, 246.98934936523438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.51967239379883, 247.49349975585938]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.73385238647461, 248.21804809570312]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.07733917236328, 249.22877502441406]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [42.411888122558594, 250.50811767578125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [40.341461181640625, 253.13662719726562]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [38.100250244140625, 262.5857849121094]. Convert image to uint8 prior to saving to suppress this warning.
# Writing generated image to /content/batch006/batch29/a.png
# WARNING:root:Lossy conversion from float32 to uint8. Range [46.85348129272461, 253.55023193359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.5988655090332, 250.6508026123047]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.252742767333984, 246.98934936523438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.51967239379883, 247.49349975585938]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.73385238647461, 248.21804809570312]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.07733917236328, 249.22877502441406]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [42.411888122558594, 250.50811767578125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [40.341461181640625, 253.13662719726562]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [38.100250244140625, 262.5857849121094]. Convert image to uint8 prior to saving to suppress this warning.
# Writing generated image to /content/batch006/batch29/a.png
# WARNING:root:Lossy conversion from float32 to uint8. Range [46.85348129272461, 253.55023193359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.5988655090332, 250.6508026123047]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.252742767333984, 246.98934936523438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.51967239379883, 247.49349975585938]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.73385238647461, 248.21804809570312]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.07733917236328, 249.22877502441406]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [42.411888122558594, 250.50811767578125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [40.341461181640625, 253.13662719726562]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [38.100250244140625, 262.5857849121094]. Convert image to uint8 prior to saving to suppress this warning.
# Writing generated image to /content/batch006/batch29/a.png
# WARNING:root:Lossy conversion from float32 to uint8. Range [46.85348129272461, 253.55023193359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.5988655090332, 250.6508026123047]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.252742767333984, 246.98934936523438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.51967239379883, 247.49349975585938]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.73385238647461, 248.21804809570312]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.07733917236328, 249.22877502441406]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [42.411888122558594, 250.50811767578125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [40.341461181640625, 253.13662719726562]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [38.100250244140625, 262.5857849121094]. Convert image to uint8 prior to saving to suppress this warning.
# Writing generated image to /content/batch006/batch29/a.png
# WARNING:root:Lossy conversion from float32 to uint8. Range [46.85348129272461, 253.55023193359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.5988655090332, 250.6508026123047]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.252742767333984, 246.98934936523438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.51967239379883, 247.49349975585938]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.73385238647461, 248.21804809570312]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.07733917236328, 249.22877502441406]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [42.411888122558594, 250.50811767578125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [40.341461181640625, 253.13662719726562]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [38.100250244140625, 262.5857849121094]. Convert image to uint8 prior to saving to suppress this warning.
# Writing generated image to /content/batch006/batch29/a.png
# WARNING:root:Lossy conversion from float32 to uint8. Range [46.85348129272461, 253.55023193359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.5988655090332, 250.6508026123047]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.252742767333984, 246.98934936523438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.51967239379883, 247.49349975585938]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.73385238647461, 248.21804809570312]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [45.07733917236328, 249.22877502441406]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [42.411888122558594, 250.50811767578125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [40.341461181640625, 253.13662719726562]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [38.100250244140625, 262.5857849121094]. Convert image to uint8 prior to saving to suppress this warning.

# %%
# !zip -r /content/drive/MyDrive/LFW0118/batch006.zip /content/batch006/
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/batch006/batch22/a.pngb'Wearing_Necktie'.png5.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Double_Chin'.png6.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Black_Hair'.png5.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Bald'.png6.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Double_Chin'.png4.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Wearing_Necklace'.png1.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Black_Hair'.png1.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Big_Nose'.png9.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Straight_Hair'.png5.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Receding_Hairline'.png4.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Oval_Face'.png8.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Heavy_Makeup'.png6.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'High_Cheekbones'.png3.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Pointy_Nose'.png8.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'5_o_Clock_Shadow'.png6.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Male'.png5.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'5_o_Clock_Shadow'.png2.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Wearing_Necklace'.png2.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Heavy_Makeup'.png1.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Double_Chin'.png7.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Goatee'.png2.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Sideburns'.png5.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Mouth_Slightly_Open'.png1.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Big_Lips'.png7.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Big_Lips'.png8.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Black_Hair'.png7.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Male'.png6.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Straight_Hair'.png3.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'5_o_Clock_Shadow'.png1.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Mustache'.png6.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Eyeglasses'.png9.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Wearing_Necktie'.png6.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Bushy_Eyebrows'.png5.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Wearing_Lipstick'.png4.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Wearing_Hat'.png4.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Pointy_Nose'.png9.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Mustache'.png4.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Mouth_Slightly_Open'.png2.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Big_Nose'.png2.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Mustache'.png7.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Receding_Hairline'.png2.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'No_Beard'.png6.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Double_Chin'.png8.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Narrow_Eyes'.png8.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Wearing_Earrings'.png3.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Mustache'.png3.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Brown_Hair'.png5.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Pointy_Nose'.png1.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Chubby'.png2.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Pale_Skin'.png9.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Mouth_Slightly_Open'.png8.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Wearing_Necktie'.png7.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Double_Chin'.png2.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Bangs'.png6.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Brown_Hair'.png2.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Mustache'.png2.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Goatee'.png7.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Pale_Skin'.png2.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Goatee'.png9.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Bushy_Eyebrows'.png6.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Bushy_Eyebrows'.png2.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Male'.png1.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Bald'.png9.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Gray_Hair'.png2.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Big_Nose'.png3.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Attractive'.png8.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Big_Lips'.png9.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Blurry'.png9.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Chubby'.png4.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'No_Beard'.png5.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Bangs'.png9.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Sideburns'.png8.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Straight_Hair'.png7.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Sideburns'.png4.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'No_Beard'.png3.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Bags_Under_Eyes'.png9.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Big_Nose'.png7.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Wearing_Hat'.png8.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Wearing_Necktie'.png8.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'5_o_Clock_Shadow'.png4.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Oval_Face'.png5.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Big_Lips'.png3.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Receding_Hairline'.png8.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Gray_Hair'.png7.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Black_Hair'.png6.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Wearing_Earrings'.png7.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Bangs'.png2.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Wearing_Necklace'.png6.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Rosy_Cheeks'.png2.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Blurry'.png7.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Wearing_Necktie'.png4.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Wavy_Hair'.png2.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Narrow_Eyes'.png3.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Black_Hair'.png9.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Black_Hair'.png3.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Mustache'.png9.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Brown_Hair'.png4.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Heavy_Makeup'.png9.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Double_Chin'.png1.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'No_Beard'.png9.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Chubby'.png1.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Double_Chin'.png5.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Wavy_Hair'.png7.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Gray_Hair'.png1.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Bangs'.png8.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Bald'.png1.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Receding_Hairline'.png1.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Wavy_Hair'.png5.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Wearing_Necktie'.png2.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'High_Cheekbones'.png8.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Oval_Face'.png9.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Oval_Face'.png1.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Big_Nose'.png6.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Straight_Hair'.png6.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Blond_Hair'.png1.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Young'.png7.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Wearing_Necktie'.png3.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Bushy_Eyebrows'.png7.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Narrow_Eyes'.png4.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Wearing_Lipstick'.png9.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Sideburns'.png6.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Narrow_Eyes'.png6.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Chubby'.png9.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Big_Nose'.png8.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Bags_Under_Eyes'.png5.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Wearing_Necktie'.png1.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Smiling'.png3.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Male'.png8.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Goatee'.png4.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Receding_Hairline'.png7.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Blurry'.png6.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Bangs'.png1.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Heavy_Makeup'.png8.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Attractive'.png5.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Bangs'.png4.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'Eyeglasses'.png2.png (stored 0%)
#   adding: content/batch006/batch22/a.pngb'