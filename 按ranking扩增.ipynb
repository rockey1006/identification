# %% [markdown]
# <a href="https://colab.research.google.com/github/rockey1006/identification/blob/main/%E6%8C%89ranking%E6%89%A9%E5%A2%9E.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from zipfile import ZipFile
with ZipFile('/content/drive/MyDrive/LFW_VERIFIED0128/batch002_verified.zip', 'r') as zipObj:
   # Extract all the contents of zip file in different directory
   zipObj.extractall('/')

# %%
from zipfile import ZipFile
with ZipFile('/content/drive/MyDrive/LFW_one1.zip', 'r') as zipObj:
   # Extract all the contents of zip file in different directory
   zipObj.extractall('/content/LFW_AUG20')

# %%
import os

srcPath="/content/batch023_verified/"
dstPath =  "/content/LFW_AUG20/content/LFW_one1/"
def copyfile(srcPath,dstPath):
   
    
    for name_file in os.listdir(dstPath):
      keyword=name_file
      #print(keyword)
      for name_file1 in os.listdir(srcPath):
        if keyword in name_file1:
          #print(keyword)
          count=0
          count2 = 200
          for file in sorted(os.listdir(srcPath+name_file1)):
            print(file)
            path = os.path.join(srcPath+str(name_file1)+'/'+file)
            with open(path, 'rb') as rstream:
              container = rstream.read()
              path2 = os.path.join(dstPath+str(name_file)+'/'+ str(name_file)+'_0%3d'%(count2)+'_0.png')
              
              if count <2:
                with open(path2, 'wb') as wstream:
                  wstream.write(container)
                  print(path2)
                  count2+=1
                  count+=1
copyfile(srcPath,dstPath)
# Out:
# 1.0062431
# /content/LFW_AUG20/content/LFW_one1/George_W_Bush/George_W_Bush_0200_0.png
# 1.0064291
# /content/LFW_AUG20/content/LFW_one1/George_W_Bush/George_W_Bush_0201_0.png
# 1.014302
# 1.0195092
# 1.0214748
# 1.0236065
# 1.0248526
# 1.0248837
# 1.026671
# 1.026824
# 1.0288107
# 1.0300639
# 1.033036
# 1.033617
# 1.0345621
# 1.0361924
# 1.0371699
# 1.0389282
# 1.0419811
# 1.043806
# 1.0440708
# 1.0451275
# 1.046194
# 1.0462332
# 1.0468465
# 1.0472383
# 1.0479586
# 1.0507041
# 1.0515552
# 1.051605
# 1.0517924
# 1.0518686
# 1.0540924
# 1.0547535
# 1.0555823
# 1.0572906
# 1.058716
# 1.0588089
# 1.0589138
# 1.0594774
# 1.0607859
# 1.0617983
# 1.0652766
# 1.065378
# 1.0655483
# 1.0668635
# 1.0668932
# 1.0689669
# 1.0719615
# 1.0733322
# 1.074912
# 1.0749547
# 1.0764723
# 1.0765766
# 1.0774491
# 1.0790975
# 1.0795587
# 1.0826521
# 1.0826904
# 1.0855479
# 1.0862747
# 1.08649
# 1.0869809
# 1.0874971
# 1.0884917
# 1.0897117
# 1.0908748
# 1.0914718
# 1.093913
# 1.0943141
# 1.0945767
# ...

# %%
# !zip -r /content/drive/MyDrive/AGU0303/LFW_agu20new.zip /content/LFW_AUG20/content/LFW_one1/
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/LFW_AUG20/content/LFW_one1/Zelma_Novelo/Zelma_Novelo_0001_0.png (deflated 0%)
#   adding: content/LFW_AUG20/content/LFW_one1/Hamid_Reza_Asefi/ (stored 0%)
#   adding: content/LFW_AUG20/content/LFW_one1/Hamid_Reza_Asefi/Hamid_Reza_Asefi_0001_0.png (deflated 0%)
#   adding: content/LFW_AUG20/content/LFW_one1/Bill_Cartwright/ (stored 0%)
#   adding: content/LFW_AUG20/content/LFW_one1/Bill_Cartwright/Bill_Cartwright_0001_0.png (deflated 0%)
#   adding: content/LFW_AUG20/content/LFW_one1/Mekhi_Phifer/ (stored 0%)
#   adding: content/LFW_AUG20/content/LFW_one1/Mekhi_Phifer/Mekhi_Phifer_0001_0.png (deflated 0%)
#   adding: content/LFW_AUG20/content/LFW_one1/Marcos_Milinkovic/ (stored 0%)
#   adding: content/LFW_AUG20/content/LFW_one1/Marcos_Milinkovic/Marcos_Milinkovic_0001_0.png (deflated 0%)
#   adding: content/LFW_AUG20/content/LFW_one1/Laurie_Chan/ (stored 0%)
# ...
