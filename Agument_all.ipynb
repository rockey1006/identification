# %% [markdown]
# <a href="https://colab.research.google.com/github/rockey1006/identification/blob/main/Agument_all.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from zipfile import ZipFile
with ZipFile('/content/drive/MyDrive/LFW_one1_agu_all.zip', 'r') as zipObj:
   # Extract all the contents of zip file in different directory
   zipObj.extractall('/agu_all')

# %%
from zipfile import ZipFile
with ZipFile('/content/drive/MyDrive/LFW_one1.zip', 'r') as zipObj:
   # Extract all the contents of zip file in different directory
   zipObj.extractall('/')

# %%
# !git clone https://github.com/rockey1006/classifier_1110.git
# Out:
# Cloning into 'classifier_1110'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 15 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (15/15), done.

# %%
from zipfile import ZipFile
with ZipFile('/content/drive/My Drive/vgg_face_weights.zip', 'r') as zipObj:
   # Extract all the contents of zip file in different directory
   zipObj.extractall('vgg_face_weights/')

# %% [markdown]
# # After agumentation

# %%
# !python /content/classifier_1110/Face2020.py
# Out:
# 2021-02-05 06:01:10.246430: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-02-05 06:01:14.231011: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-02-05 06:01:14.231144: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-02-05 06:01:14.231294: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-05 06:01:14.231919: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla V100-SXM2-16GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 15.75GiB deviceMemoryBandwidth: 836.37GiB/s
# ...

# %% [markdown]
# # Before Agumentation

# %%
# !python /content/classifier_1110/Face2020.py
# Out:
# 2021-02-05 04:29:14.450767: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-02-05 04:29:18.530659: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-02-05 04:29:18.530806: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-02-05 04:29:18.530964: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-05 04:29:18.531618: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla V100-SXM2-16GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 15.75GiB deviceMemoryBandwidth: 836.37GiB/s
# ...
